# %%
import requests
from bs4 import BeautifulSoup
import time
import requests

endpoint = "https://api.agify.io?"
gender_endpoint = "https://api.genderize.io?"
parameters = {
    "name":"Linda",
}

response = requests.get(endpoint,params=parameters)
res = requests.get(gender_endpoint,params=parameters)
response.raise_for_status
data = response.json()
data1 = res.json()
data1
# Out:
# {'count': 754202, 'gender': 'female', 'name': 'Linda', 'probability': 1.0}

# %%
r = requests.get("https://www.800score.com/gre-prep/prep-guide/gre-vocabulary-list/") #將網頁資料GET下來
soup = BeautifulSoup(r.text,"html.parser") #將網頁資料以html.parser
sel = soup.select("tbody td") #取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel
for s in sel:
    print(s.text)
# Out:
# abacus
# frame with balls used for calculating
# abate
# to lessen, subside
# abdication
# formal relinquishing of power or authority; resignation
# aberration
# straying away from what is natural or normal; deviation
# abet
# to help, encourage someone in wrongdoing
# abeyance
# suspended action; temporary inactivity
# abhor
# to hate, detest
# abide
# to be faithful; to endure
# abjure
# to promise or swear to give up
# abraded
# rubbed off, worn away by friction
# abrogate
# to repeal or annul by authority
# abscond
# to go away suddenly (to avoid arrest)
# abstruse
# difficult to comprehend; obscure
# abut
# to border on
# abysmal
# bottomless; profoundly, extremely bad
# acarpous
# effete; worn out; sterile; no longer fertile
# acclaimed
# welcomed with shouts and approval
# accolade
# praise, approval
# accretion
# the growing of separate things into one; an addition
# adamant
# kind of stone; inflexible
# admonitory
# containing a warning; tending to admonish
# adorn
# ...

# %%
import datetime
now = datetime.datetime.now()
current = now.strftime('2022/%m/%d')
current
# Out:
# '2022/11/03'

# %%
import requests
endpoint = "https://api.npoint.io/4cedc647e52fc72c2543"
response = requests.get(endpoint).json()
response
for i in response:
    print(i.title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/kuanhungchao/Documents/python_project/100days-python/test_bug.ipynb Cell 4 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/kuanhungchao/Documents/python_project/100days-python/test_bug.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> response
#       <a href='vscode-notebook-cell:/Users/kuanhungchao/Documents/python_project/100days-python/test_bug.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> for i in response:
# ----> <a href='vscode-notebook-cell:/Users/kuanhungchao/Documents/python_project/100days-python/test_bug.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     print(i.title)
#
# AttributeError: 'dict' object has no attribute 'title'

# %%
sel[0].text
w_list = []
for index, element in enumerate(sel):
    if index %2 == 0:
        w_list.append(element.text)
        
w_list1 = ",\n".join(w_list)
with open("vocabulary.txt","w") as file:
    file.write(w_list1)

# %%
import pandas as pd
df = pd.read_csv("vocabulary.txt")

# %%
w_list
df1 = pd.DataFrame(w_list).to_csv("vocabulary.csv")

# %%
from bokeh.io import output_file, show
from bokeh.plotting import figure

output_file("bar_sorted.html")

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

# sorting the bars means sorting the range factors
sorted_fruits = sorted(fruits, key=lambda x: counts[fruits.index(x)])

p = figure(x_range=sorted_fruits, height=350, title="Fruit counts",
           toolbar_location=None, tools="")

p.vbar(x=fruits, top=counts, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)

# %%
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
