# %%
import requests
import pandas as pd

SHEETY_ENDPOINT = "https://api.sheety.co/0cc72aeabea665e303c02d94a6fbb2d2/flightDeals/prices"

SHEERY_TOKEN = {
    "Authorization": "Bearer 12344321chaefewierj",
}

response = requests.get(url=SHEETY_ENDPOINT,headers=SHEERY_TOKEN)
data =response.json()
data['prices']
# Out:
# list

# %%
TEQUILA_ENDPOINT ="https://api.tequila.kiwi.com"
TEQUILA_API_KEY = "oqlraJL_01ZdEhfETZC1LgJ45Tg6_Ug8"



location_endpoint = f"{TEQUILA_ENDPOINT}/locations/query"
headers = {"apikey":TEQUILA_API_KEY}
query = {
    "term": "Paris",
    "location_types": "city"
    }
response_flight = requests.get(url=location_endpoint,headers=headers,params=query)
a = response_flight.json()
a
# Out:
# {'locations': [{'id': 'paris_fr',
#    'active': True,
#    'name': 'Paris',
#    'slug': 'paris-france',
#    'slug_en': 'paris-france',
#    'code': 'PAR',
#    'alternative_names': [],
#    'rank': 8,
#    'global_rank_dst': 3,
#    'dst_popularity_score': 6396245.0,
#    'timezone': 'Europe/Paris',
#    'population': 2138551,
#    'airports': 4,
#    'stations': 8,
#    'hotels': 3779,
#    'bus_stations': 11,
#    'subdivision': None,
#    'autonomous_territory': None,
#    'country': {'id': 'FR', 'name': 'France', 'slug': 'france', 'code': 'FR'},
#    'region': {'id': 'western-europe',
#     'name': 'Western Europe',
#     'slug': 'western-europe'},
#    'continent': {'id': 'europe',
#     'name': 'Europe',
#     'slug': 'europe',
#     'code': 'EU'},
#    'nearby_country': None,
#    'location': {'lat': 48.856614, 'lon': 2.352222},
#    'tags': [{'tag': 'city break', 'month_to': -1, 'month_from': -1},
#     {'tag': 'culture', 'month_to': -1, 'month_from': -1},
# ...
